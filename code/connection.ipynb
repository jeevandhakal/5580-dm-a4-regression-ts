# %%
import pandas as pd 
import numpy as np 


import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from utils import time_operation

# %%
data_path = Path().cwd().parent / "data" / "electricity_prediction.csv"
results_path = Path().cwd().parent / "results"

# %% [markdown]
# ## 1. Connect to data

# %%
df = pd.read_csv(data_path)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 139570 entries, 0 to 139569
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   71.77033493    139570 non-null  float64
#  1   320.5741627    139570 non-null  float64
#  2   401.9138756    139570 non-null  float64
#  3   344.4976077    139570 non-null  float64
#  4   440.1913876    139570 non-null  float64
#  5   440.1913876.1  139570 non-null  float64
#  6   425.8373206    139570 non-null  float64
# dtypes: float64(7)
# memory usage: 7.5 MB
